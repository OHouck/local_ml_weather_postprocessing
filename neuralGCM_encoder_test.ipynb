# %%
import jax
import matplotlib.pyplot as plt
import numpy as np
import neuralgcm
import pprint
import xarray

checkpoint = neuralgcm.demo.load_checkpoint_tl63_stochastic()
model = neuralgcm.PressureLevelModel.from_checkpoint(checkpoint)

# %%
ds = neuralgcm.demo.load_data(model.data_coords)
ds_init = ds.isel(time=0)
inputs, forcings = model.data_from_xarray(ds_init)

# %%
encoded = model.encode(inputs, forcings)
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/Users/ohouck/envs/ai_weather_ag_venv/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3508, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/f1/ns9p3knx5tn5wf7rkr_cd9dw0000gn/T/ipykernel_77901/2697419791.py", line 1, in <module>
#     encoded = model.encode(inputs, forcings)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ohouck/envs/ai_weather_ag_venv/lib/python3.11/site-packages/jax/_src/traceback_util.py", line 179, in reraise_with_filtered_traceback
#     return fun(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ohouck/envs/ai_weather_ag_venv/lib/python3.11/site-packages/jax/_src/pjit.py", line 327, in cache_miss
#     outs, out_flat, out_tree, args_flat, jaxpr, attrs_tracked = _python_pjit_helper(
#                                                                 ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ohouck/envs/ai_weather_ag_venv/lib/python3.11/site-packages/jax/_src/pjit.py", line 175, in _python_pjit_helper
#     attrs_tracked) = _infer_params(jit_info, args, kwargs)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ohouck/envs/ai_weather_ag_venv/lib/python3.11/site-packages/jax/_src/pjit.py", line 630, in _infer_params
#     device_or_backend_set, HashableFunction(out_tree, closure=()),
#
#   File "/Users/ohouck/envs/ai_weather_ag_venv/lib/python3.11/site-packages/jax/_src/pjit.py", line 1278, in _pjit_jaxpr
#     canonicalized_out_shardings_flat, out_layouts_flat = _check_and_canonicalize_out_shardings(
#                                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ohouck/envs/ai_weather_ag_venv/lib/python3.11/site-packages/jax/_src/linear_util.py", line 350, in memoized_fun
#     ans = call(fun, *args)
#           ^^^^^^^^^^^^^^^^
#   File "/Users/ohouck/envs/ai_weather_ag_venv/lib/python3.11/site-packages/jax/_src/pjit.py", line 1192, in _create_pjit_jaxpr
#   File "/Users/ohouck/envs/ai_weather_ag_venv/lib/python3.11/site-packages/jax/_src/profiler.py", line 335, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ohouck/envs/ai_weather_ag_venv/lib/python3.11/site-packages/jax/_src/interpreters/partial_eval.py", line 2347, in trace_to_jaxpr_dynamic
#     jaxpr, out_avals, consts, attrs_tracked = trace_to_subjaxpr_dynamic(
#                                               ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ohouck/envs/ai_weather_ag_venv/lib/python3.11/site-packages/jax/_src/interpreters/partial_eval.py", line 2370, in trace_to_subjaxpr_dynamic
#     ans = fun.call_wrapped(*in_tracers_)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ohouck/envs/ai_weather_ag_venv/lib/python3.11/site-packages/jax/_src/linear_util.py", line 192, in call_wrapped
#     ans = self.f(*args, **dict(self.params, **kwargs))
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ohouck/envs/ai_weather_ag_venv/lib/python3.11/site-packages/neuralgcm/api.py", line 87, in _method
#     return method(self, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ohouck/envs/ai_weather_ag_venv/lib/python3.11/site-packages/neuralgcm/api.py", line 423, in encode
#     return self._structure.encode_fn(self.params, rng_key, inputs, f)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ohouck/envs/ai_weather_ag_venv/lib/python3.11/site-packages/haiku/_src/transform.py", line 183, in apply_fn
#     out, state = f.apply(params, None, *args, **kwargs)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ohouck/envs/ai_weather_ag_venv/lib/python3.11/site-packages/haiku/_src/transform.py", line 456, in apply_fn
#     out = f(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^
#   File "/Users/ohouck/envs/ai_weather_ag_venv/lib/python3.11/site-packages/neuralgcm/model_builder.py", line 609, in <lambda>
#     encode_fwd = lambda x, forcing: model_cls().encode(x, forcing)
#                                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ohouck/envs/ai_weather_ag_venv/lib/python3.11/site-packages/haiku/_src/module.py", line 465, in wrapped
#   File "/opt/homebrew/Cellar/python@3.11/3.11.9/Frameworks/Python.framework/Versions/3.11/lib/python3.11/contextlib.py", line 81, in inner
#     return func(*args, **kwds)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.11/3.11.9/Frameworks/Python.framework/Versions/3.11/lib/python3.11/contextlib.py", line 81, in inner
#     return func(*args, **kwds)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/Users/ohouck/envs/ai_weather_ag_venv/lib/python3.11/site-packages/haiku/_src/module.py", line 306, in run_interceptors
#   File "/Users/ohouck/envs/ai_weather_ag_venv/lib/python3.11/site-packages/neuralgcm/model_builder.py", line 468, in encode
#     model_state = self.encoder_fn(x, forcing=forcing)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ohouck/envs/ai_weather_ag_venv/lib/python3.11/site-packages/haiku/_src/module.py", line 465, in wrapped
#   File "/opt/homebrew/Cellar/python@3.11/3.11.9/Frameworks/Python.framework/Versions/3.11/lib/python3.11/contextlib.py", line 81, in inner
#     return func(*args, **kwds)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/Users/ohouck/envs/ai_weather_ag_venv/lib/python3.11/site-packages/haiku/_src/module.py", line 306, in run_interceptors
#   File "/Users/ohouck/envs/ai_weather_ag_venv/lib/python3.11/site-packages/neuralgcm/encoders.py", line 795, in __call__
#     return super().__call__(nondim_inputs, forcing)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ohouck/envs/ai_weather_ag_venv/lib/python3.11/site-packages/haiku/_src/module.py", line 465, in wrapped
#   File "/opt/homebrew/Cellar/python@3.11/3.11.9/Frameworks/Python.framework/Versions/3.11/lib/python3.11/contextlib.py", line 81, in inner
#     return func(*args, **kwds)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/Users/ohouck/envs/ai_weather_ag_venv/lib/python3.11/site-packages/haiku/_src/module.py", line 306, in run_interceptors
#   File "/Users/ohouck/envs/ai_weather_ag_venv/lib/python3.11/site-packages/neuralgcm/encoders.py", line 602, in __call__
#     randomness = self.randomness_fn.unconditional_sample(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ohouck/envs/ai_weather_ag_venv/lib/python3.11/site-packages/haiku/_src/module.py", line 465, in wrapped
#   File "/opt/homebrew/Cellar/python@3.11/3.11.9/Frameworks/Python.framework/Versions/3.11/lib/python3.11/contextlib.py", line 81, in inner
#     return func(*args, **kwds)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.11/3.11.9/Frameworks/Python.framework/Versions/3.11/lib/python3.11/contextlib.py", line 81, in inner
#     return func(*args, **kwds)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/Users/ohouck/envs/ai_weather_ag_venv/lib/python3.11/site-packages/haiku/_src/module.py", line 306, in run_interceptors
#   File "/Users/ohouck/envs/ai_weather_ag_venv/lib/python3.11/site-packages/neuralgcm/stochastic.py", line 739, in unconditional_sample
#     rngs = jax.random.split(rng, self.n_fields + 1)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ohouck/envs/ai_weather_ag_venv/lib/python3.11/site-packages/jax/_src/random.py", line 277, in split
#     typed_key, wrapped = _check_prng_key("split", key)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ohouck/envs/ai_weather_ag_venv/lib/python3.11/site-packages/jax/_src/random.py", line 99, in _check_prng_key
#     raise TypeError(f'unexpected PRNG key type {type(key)}')
# TypeError: unexpected PRNG key type <class 'NoneType'>
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/ohouck/envs/ai_weather_ag_venv/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 2105, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ohouck/envs/ai_weather_ag_venv/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1396, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ohouck/envs/ai_weather_ag_venv/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1287, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ohouck/envs/ai_weather_ag_venv/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1140, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ohouck/envs/ai_weather_ag_venv/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1055, in format_exception_as_a_whole
#     frames.append(self.format_record(record))
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ohouck/envs/ai_weather_ag_venv/lib/python3.11/site-packages/IPython/core/ultratb.py", line 955, in format_record
#     frame_info.lines, Colors, self.has_colors, lvals
#     ^^^^^^^^^^^^^^^^
#   File "/Users/ohouck/envs/ai_weather_ag_venv/lib/python3.11/site-packages/IPython/core/ultratb.py", line 778, in lines
#     return self._sd.lines
#            ^^^^^^^^^^^^^^
#   File "/Users/ohouck/envs/ai_weather_ag_venv/lib/python3.11/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "/Users/ohouck/envs/ai_weather_ag_venv/lib/python3.11/site-packages/stack_data/core.py", line 734, in lines
#     pieces = self.included_pieces
#              ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ohouck/envs/ai_weather_ag_venv/lib/python3.11/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "/Users/ohouck/envs/ai_weather_ag_venv/lib/python3.11/site-packages/stack_data/core.py", line 681, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#                              ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ohouck/envs/ai_weather_ag_venv/lib/python3.11/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "/Users/ohouck/envs/ai_weather_ag_venv/lib/python3.11/site-packages/stack_data/core.py", line 660, in executing_piece
#     return only(
#            ^^^^^
#   File "/Users/ohouck/envs/ai_weather_ag_venv/lib/python3.11/site-packages/executing/executing.py", line 116, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0
